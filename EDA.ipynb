# %%
#Imports
import pandas as pd

ncaa = pd.read_csv('Data/ncaa_data.csv')

ncaa.head()
# Out:
#             Player   Season         Team  GP  GS   MP   FG  FGA   2P  2PA  \
# 0  James Bouknight  2020-21  Connecticut  15  14  475   98  219   76  144
# 1     Caris LeVert  2015-16     Michigan  15  14  464   82  162   53   97
# 2      B.J. Taylor  2017-18          UCF  16  14  495   80  201   54  134
# 3   Emanuel Miller  2020-21    Texas A&M  17  13  538  100  175  100  169
# 4       Dylan Disu  2020-21   Vanderbilt  17  17  537   89  181   65  116
#
#    ...  PTS    FG%    2P%    3P%    FT%    TS%   eFG%  POS  Class   Drafted
# 0  ...  281  0.447  0.528  0.293  0.778  0.546  0.498    G      SO        1
# 1  ...  247  0.506  0.546  0.446  0.794  0.636  0.596    G      SR        1
# 2  ...  254  0.398  0.403  0.388  0.673  0.510  0.463    G      JR        0
# 3  ...  276  0.571  0.592  0.000  0.817  0.630  0.571    F      SO        0
# 4  ...  255  0.492  0.560  0.369  0.736  0.592  0.558    F      SO        0
#
# [5 rows x 32 columns]
